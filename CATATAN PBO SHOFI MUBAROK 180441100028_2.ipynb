# %% [markdown]
# # METHOD DAN OPERATOR OVERLOADING
# __A. PENGERTIAN METHOD OVERLOADING__
#
# ![1a.PNG](attachment:1a.png)
#
# Method Overloading adalah kemampuan untuk mendefinisikan suatu method yang sama, dengan nama yang sama tetapi dengan jumlah argumen dan tipe yang berbeda. Termasuk juga kemampuan suatu fungsi untuk melakukan tugas yang berbeda, tergantung pada jumlah parameter atau jenis parameter. Perlu diketahui bahwa tidak semua bahasa pemrograman mendukung method overloading, tetapi Python dapat melakukannya.
#
# Lihatlah contoh dibawah ini :
#
# ![2a.PNG](attachment:2a.PNG)
#
# Pada program diatas mengalami error karena terdapat dua method yang sama tetapi memiliki argumen yang berbeda. Di python jika terdapat dua method yang sama dalam satu kelas maka method yang paling bawah yang menjadi patokan. Untuk itu perlu dilakukan method overloading (Pemanggilan 2 buah method yang sama).
#
# ![3a.PNG](attachment:3a.PNG)
#
# __B. PENGERTIAN OPERATOR OVERLOADING__
#
# ![7.PNG](attachment:7.PNG)
#
# Operator Overloading berarti memberikan makna yang diperluas di luar makna operasional yang telah ditentukan sebelumnya. Misalnya operator + digunakan untuk menambahkan dua bilangan bulat serta menggabungkan dua string.
#
# Operator overloading dapat di capai dengan mendefenisikan method khusus dalam definisi suatu kelas. Method inilah yang dinamakan "Magic Method". Berikut beberapa jenis magic method :
#
# ![4a.PNG](attachment:4a.PNG)
# ![5.PNG](attachment:5.PNG)
# ![6.PNG](attachment:6.PNG)
#
# Berikut Contoh penerapan operator overloading dan magic method :
# ![8.PNG](attachment:8.PNG)
#
# Pada contoh diatas yakni penggunaan magic method berupa __ add __ ,dan, __ sub __ untuk menjumlahkan dan mengurangi dua buah bilangan bulat dan penggunaan __ str __ untuk mencetak hasil berupa tipe data string.
#
# Berikut juga contoh penerapan operator overloading dan magic method :
# ![9.PNG](attachment:9.PNG)
#
# Pada contoh diatas sama dengan penjelasannya tetapi ini menjumlahkan tipe data berupa string.

# %% [markdown]
# # ENCAPSULATION
#
# __A. PENGERTIAN ENCAPSULATION__
#
#  ![1.png](attachment:1.png)
#  Encapsulation adalah pembungkus, maksud pembungkus disini adalah untuk menjaga suatu proses program agar tidak dapat diakses secara sembarangan atau di intervensi oleh program lain. Konsep enkapsulasi sangat penting dilakukan untuk menjaga kebutuhan program agar dapat diakses sewaktu-waktu, sekaligus menjaga program tersebut.
#  Dalam konsep ini ada dua kata kunci yang digunakan, yakni private dan public :
#
# - Private memberikan hak akses __hanya__ kepada anggota class tersebut untuk menggunakan dan/atau mengubah nilai dari property atau method tersebut
# - Public memberikan hak akses kepada semua property dan method agar dapat digunakan diluar class tersebut
#
# ![2.PNG](attachment:2.PNG)
#
# Seperti contoh diatas, untuk method yang pertama ( PrintName ) masih bisa berjalan karena itu merupakan method dan variabel yang bersifat public. Sedangkan untuk method yang terakhir ( __PrintNIM ) terjadi error dikeranakan itu bersifat privat.
#
# Agar tidak terjadi error yang harus dilakukan ada 2 cara yaitu:
#
# - Sebelum double underscore diberi _(NAMA CLASS)
# ![3.PNG](attachment:3.PNG)
# - Menggunakan Method baru get/set
# ![4.PNG](attachment:4.PNG)
